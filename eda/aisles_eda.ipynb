# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Admin\PROJECT\Project_instacart\data\aisles.csv')

# %%
print(f"\nTotal rows: {len(df)}")
print("\nFirst few rows:")
print(df.head(2))

print("\nData types:")
print(df.dtypes)
# Out:
# Total rows: 134
#
# First few rows:
#    aisle_id                  aisle
# 0         1  prepared soups salads
# 1         2      specialty cheeses
#
# Data types:
# aisle_id     int64
# aisle       object
# dtype: object

# %%
print("\nBasic statistics:")
print(df.describe())
# Out:
# Basic statistics:
#          aisle_id
# count  134.000000
# mean    67.500000
# std     38.826537
# min      1.000000
# 25%     34.250000
# 50%     67.500000
# 75%    100.750000
# max    134.000000
