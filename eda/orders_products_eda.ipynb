# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Admin\PROJECT\Project_instacart\data\order_products_filtered_2025.csv')

# %%
print(f"\nTotal rows: {len(df)}")

print("\nFirst few rows:")
print(df.head(2))

print("\nData types:")
print(df.dtypes)
# Out:
# Total rows: 27026
#
# First few rows:
#    order_id  product_id  add_to_cart_order  reordered
# 0      1483       32818                  1          1
# 1      1483       27582                  2          1
#
# Data types:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
print("\nBasic statistics:")
print(df.describe())
# Out:
# Basic statistics:
#            order_id    product_id  add_to_cart_order     reordered
# count  2.702600e+04  27026.000000       27026.000000  27026.000000
# mean   1.736760e+06  25567.348294           7.816658      0.553134
# std    9.956820e+05  14281.189518           6.658373      0.497178
# min    1.483000e+03      1.000000           1.000000      0.000000
# 25%    8.940150e+05  13176.000000           3.000000      0.000000
# 50%    1.723760e+06  25627.000000           6.000000      1.000000
# 75%    2.616102e+06  37705.750000          11.000000      1.000000
# max    3.415043e+06  49683.000000          58.000000      1.000000
