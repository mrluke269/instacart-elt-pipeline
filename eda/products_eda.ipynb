# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Admin\PROJECT\Project_instacart\data\products.csv')

# %%
print(f"\nTotal rows: {len(df)}")
print("\nFirst few rows:")
print(df.head(2))

print("\nData types:")
print(df.dtypes)
# Out:
# Total rows: 49688
#
# First few rows:
#    product_id                product_name  aisle_id  department_id
# 0           1  Chocolate Sandwich Cookies        61             19
# 1           2            All-Seasons Salt       104             13
#
# Data types:
# product_id        int64
# product_name     object
# aisle_id          int64
# department_id     int64
# dtype: object
